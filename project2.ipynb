# %% [markdown]
# # Project 2: Web Scraping and API access

# %%
# !pip install beautifulsoup4

# %% [markdown]
# ## Part 1: Explore the html for Wikipedia articles.

# %% [markdown]
# ### A. Using inspect element, copy the html code for a table.

# %% [markdown]
# <table class="wikitable plainrowheaders">
# <caption>Confirmed casualties
# </caption>
# <tbody><tr>
# <th scope="col">
# </th>
# <th scope="col">Numbers
# </th>
# <th scope="col">Time period
# </th>
# <th scope="col">Source
# </th></tr>
# <tr>
# <th scope="row"><b>Ukrainian civilians</b>
# </th>
# <td><b>12,654</b> killed, <b>27,836</b> wounded
# </td>
# <td>24 February 2022 – 21 February 2025
# </td>
# <td>United Nations (<a href="/wiki/OHCHR" class="mw-redirect" title="OHCHR">OHCHR</a>)<sup id="cite_ref-582" class="reference"><a href="#cite_note-582"><span class="cite-bracket">[</span>577<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <th scope="row"><b>Ukrainian forces</b> (<a href="/wiki/National_Guard_of_Ukraine" title="National Guard of Ukraine">NGU</a>)
# </th>
# <td><b>501</b> killed, <b>1,697</b> wounded
# </td>
# <td>24 February 2022 – 12 May 2022
# </td>
# <td><a href="/wiki/National_Guard_of_Ukraine" title="National Guard of Ukraine">National Guard of Ukraine</a><sup id="cite_ref-583" class="reference"><a href="#cite_note-583"><span class="cite-bracket">[</span>578<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <th scope="row"><b>Ukrainian forces</b> (<a href="/wiki/Armed_Forces_of_Ukraine" title="Armed Forces of Ukraine">ZSU</a>)
# </th>
# <td><b>46,000</b> killed, <b>380,000</b> wounded
# </td>
# <td>24 February 2022 – 16 February 2025
# </td>
# <td><a href="/wiki/Office_of_the_President_of_Ukraine" title="Office of the President of Ukraine">Office of the President of Ukraine</a><sup id="cite_ref-584" class="reference"><a href="#cite_note-584"><span class="cite-bracket">[</span>579<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <th scope="row"><b>Ukrainian forces</b>
# </th>
# <td><b>65,542</b> killed (incl. non-combat,<sup id="cite_ref-585" class="reference"><a href="#cite_note-585"><span class="cite-bracket">[</span>580<span class="cite-bracket">]</span></a></sup><br>confirmed by names)
# </td>
# <td>24 February 2022 – 17 February 2025
# </td>
# <td>UALosses project<sup id="cite_ref-UALosses_586-0" class="reference"><a href="#cite_note-UALosses-586"><span class="cite-bracket">[</span>581<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <th scope="row"><b>Russian forces</b><br>(<a href="/wiki/Russian_separatist_forces_in_Donbas" class="mw-redirect" title="Russian separatist forces in Donbas">DPR/LPR</a> excluded)
# </th>
# <td><b>90,019</b> killed (conf. by names)
# </td>
# <td>24 February 2022 – 24&nbsp;January 2025
# </td>
# <td><a href="/wiki/BBC_News_Russian" title="BBC News Russian">BBC News Russian</a> and <a href="/wiki/Mediazona" title="Mediazona">Mediazona</a><sup id="cite_ref-BBCMediazona_587-0" class="reference"><a href="#cite_note-BBCMediazona-587"><span class="cite-bracket">[</span>582<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <th scope="row"><b>Russian forces</b><br>(<a href="/wiki/Russian_separatist_forces_in_Donbas" class="mw-redirect" title="Russian separatist forces in Donbas">Donetsk &amp; Luhansk PR</a>)
# </th>
# <td><b>21,000–23,500</b> killed
# </td>
# <td>24 February 2022 – 30 September 2024
# </td>
# <td><a href="/wiki/BBC_News_Russian" title="BBC News Russian">BBC News Russian</a><sup id="cite_ref-BBCMediazona_587-1" class="reference"><a href="#cite_note-BBCMediazona-587"><span class="cite-bracket">[</span>582<span class="cite-bracket">]</span></a></sup>
# </td></tr></tbody></table>

# %% [markdown]
# ### B. Using inspect element, find the html syntax for a link.

# %% [markdown]
# <a href="/wiki/President_of_the_United_States" title="President of the United States">president of the United States</a>

# %% [markdown]
# ### C. Using inspect element, find the html syntax for linking an image

# %% [markdown]
# <img alt="Head-and-shoulders portrait of Trump with a stern facial expression. He is wearing a blue suit, a white shirt, a blue necktie, and an American flag lapel pin. The background is unlit and blurred, and part of an American flag is visible." src="//upload.wikimedia.org/wikipedia/commons/thumb/8/83/TrumpPortrait.jpg/220px-TrumpPortrait.jpg" decoding="async" width="220" height="285" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/83/TrumpPortrait.jpg/330px-TrumpPortrait.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/83/TrumpPortrait.jpg/440px-TrumpPortrait.jpg 2x" data-file-width="2550" data-file-height="3300">

# %% [markdown]
# ## Part 2: Explore one Wikipedia page with the beautifulsoup package

# %%
import bs4
import requests
import pandas as pd
import os

# %%
#save and print the text content of a page with all tags removed
url = "https://en.wikipedia.org/wiki/Donald_Trump" 

# Fetch the page
response = requests.get(url)
soup = bs4.BeautifulSoup(response.text, "html.parser")

text_content = soup.get_text()

with open("wikipedia_text.txt", "w", encoding="utf-8") as file:
    file.write(text_content)

print(text_content[:1000])
# Out:
# Donald Trump - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload fileSpecial pages
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
# Donate Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1
# Early life and education
#
#
#
#
#
#
#
#
# 2
# Business career
#
#
#
#
# Toggle Business career subsection
#
#
#
#
#
# 2.1
# ...

# %%
#download an image with beautifulsoup and save it in this repository
image = soup.find("img")  
image_url = "https://en.wikipedia.org/" + image["src"]

image_response = requests.get(image_url)

with open("downloaded_image.jpg", "wb") as file:
    file.write(image_response.content)

# %%
#find all the links in a page with beautifulsoup
#print the first 100 characters of ten of these links
links = soup.find_all("a", href=True)

for i, link in enumerate(links[:10]):
    link_text = link.get("href")
    print(f"Link {i+1}: {link_text[:100]}")
# Out:
# Link 1: #bodyContent
# Link 2: /wiki/Main_Page
# Link 3: /wiki/Wikipedia:Contents
# Link 4: /wiki/Portal:Current_events
# Link 5: /wiki/Special:Random
# Link 6: /wiki/Wikipedia:About
# Link 7: //en.wikipedia.org/wiki/Wikipedia:Contact_us
# Link 8: /wiki/Help:Contents
# Link 9: /wiki/Help:Introduction
# Link 10: /wiki/Wikipedia:Community_portal

# %% [markdown]
# ## Part 3: Downloading scripts

# %%
scripts=pd.read_csv('pudding_data.csv')

# %%
scripts
# Out:
#         imdb_id  script_id             title  year  \
# 0     tt0019777       4031     The Cocoanuts  1929
# 1     tt0021884       8521      Frankenstein  1931
# 2     tt0022054       1086   The Last Flight  1931
# 3     tt0022626       1631  American Madness  1932
# 4     tt0022958       2438       Grand Hotel  1932
# ...         ...        ...               ...   ...
# 1995  tt3733778       8533     Pay the Ghost  2015
# 1996  tt3808342       5499       Son of Saul  2015
# 1997  tt3850214       8056              Dope  2015
# 1998  tt3859076       5507             Truth  2015
# 1999  tt4270516       5410           Grandma  2015
#
#       gross (inflation-adjusted)  \
# 0                            NaN
# 1                          298.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         0.0
# 1997                        18.0
# ...

# %%
#using the links in the "link" column, download the first 1000 characters of each script
#use requests and bs4, remember to remove all html tags
def get_script_text(url):
    try:
        response = requests.get(url, timeout=5)
        response.raise_for_status()
        soup = bs4.BeautifulSoup(response.text, "html.parser")
        text = soup.get_text()
        return text[:1000]
    except Exception as e:
        return f"Error: {e}"

# %%
#add a new column to the df with the text downloaded
#save this new dataframe as "pudding_texts.csv"
scripts["script_text"] = scripts["link"].apply(get_script_text)

scripts.to_csv("pudding_texts.csv", index=False)

# %% [markdown]
# ## Part 4: TMDB database

# %% [markdown]
# #### Browse the documentation at https://developer.themoviedb.org/reference/intro/getting-started. Create an account to authenticate

# %%
#create a dataset of the movies in theaters now. Include metadata fields you are interested in.

# %%
#download the movie posters for 10 of these movies and save them to this repository
